# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train = pd.read_csv('train_human.csv')
test = pd.read_csv('test_human.csv')

# %%
print(train.shape,test.shape)
# Out:
# (7352, 563) (2947, 563)

# %%
pp = list(train.columns)

# %%
train['source'] = 'train'
test['source'] = 'test'

# %%
# train['subject'].value_counts()

# %%
data = pd.concat([train,test],ignore_index = True,sort = False)

# %%
print(train.shape,test.shape,data.shape)
# Out:
# (7352, 564) (2947, 564) (10299, 564)

# %%
res = {}
for i in pp:
    i = i.split('-')[0].split('(')[0]
    if i in res:
        res[i] += 1
    else:
        res[i] = 1
#     print(res)
print(res)
# Out:
# {'tBodyAcc': 40, 'tGravityAcc': 40, 'tBodyAccJerk': 40, 'tBodyGyro': 40, 'tBodyGyroJerk': 40, 'tBodyAccMag': 13, 'tGravityAccMag': 13, 'tBodyAccJerkMag': 13, 'tBodyGyroMag': 13, 'tBodyGyroJerkMag': 13, 'fBodyAcc': 79, 'fBodyAccJerk': 79, 'fBodyGyro': 79, 'fBodyAccMag': 13, 'fBodyBodyAccJerkMag': 13, 'fBodyBodyGyroMag': 13, 'fBodyBodyGyroJerkMag': 13, 'angle': 7, 'subject': 1, 'Activity': 1, 'source': 1}

# %%
val = pd.DataFrame(list(res.items()), columns =["columns","count"] )

# %%
val.sort_values(by =['count'],ascending = [False])
# Out:
#                  columns  count
# 10              fBodyAcc     79
# 12             fBodyGyro     79
# 11          fBodyAccJerk     79
# 1            tGravityAcc     40
# 0               tBodyAcc     40
# 4          tBodyGyroJerk     40
# 3              tBodyGyro     40
# 2           tBodyAccJerk     40
# 5            tBodyAccMag     13
# 6         tGravityAccMag     13
# 7        tBodyAccJerkMag     13
# 8           tBodyGyroMag     13
# 9       tBodyGyroJerkMag     13
# 13           fBodyAccMag     13
# 14   fBodyBodyAccJerkMag     13
# 15      fBodyBodyGyroMag     13
# 16  fBodyBodyGyroJerkMag     13
# 17                 angle      7
# 18               subject      1
# 19              Activity      1
# 20                source      1
